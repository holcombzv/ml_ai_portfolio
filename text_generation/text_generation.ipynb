# %%
restart = True
epoch_to_pickup = 0

# %%
# Import libraries

from tensorflow.keras.layers import StringLookup
import numpy as np
import os
import time
import random
import contextlib
import io
import re
import string
import gc  # Import the garbage collector module

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.layers import TextVectorization

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
path = ''

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path = '/content/drive/My Drive/M6_Fall2023e/'

# %% [markdown]
# ## Functions for downloading text

# %%
def preprocess_text(text):

    text = text.replace("Project Gutenberg", "")
    text = text.replace("Gutenberg", "")

    # Remove carriage returns
    text = text.replace("\r", "")

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Remove duplicate whitespace
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\n+", "\n", text)
    text = re.sub(r"\t+", "\t", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

# %%
def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

# %%
# def getMyText():
#   path_to_file = tf.keras.utils.get_file('austen.txt', 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt')

#   text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

#   # path_to_file = tf.keras.utils.get_file('903-0.txt', 'https://www.gutenberg.org/files/903/903-0.txt')
#   # author_text += open(path_to_file, 'rb').read().decode(encoding='utf-8')[2999:-19194]
#   # tf.io.gfile.remove(path_to_file)

#   return preprocess_text(text)

import os
import tensorflow as tf

def getMyText():
    file_name = 'austen.txt'
    file_url = 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt'
    local_dir = 'saved_files'  # Directory to save the file
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found locally. Downloading it.")
            # Download the file
            downloaded_path = tf.keras.utils.get_file(file_name, file_url)

            # Save the downloaded file to the designated local directory
            with open(downloaded_path, 'rb') as source_file:
                with open(local_path, 'wb') as dest_file:
                    dest_file.write(source_file.read())

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
def getMyText2():
    file_name = 'twain.txt'
    file_url = 'https://www.gutenberg.org/cache/epub/245/pg245.txt'
    local_dir = 'saved_files'  # Directory to save the file
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found locally. Downloading it.")
            # Download the file
            downloaded_path = tf.keras.utils.get_file(file_name, file_url)

            # Save the downloaded file to the designated local directory
            with open(downloaded_path, 'rb') as source_file:
                with open(local_path, 'wb') as dest_file:
                    dest_file.write(source_file.read())

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def getMyText3():
    file_name = 'poe.txt'
    file_url = 'https://www.gutenberg.org/cache/epub/25525/pg25525.txt'
    local_dir = 'saved_files'  # Directory to save the file
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found locally. Downloading it.")
            # Download the file
            downloaded_path = tf.keras.utils.get_file(file_name, file_url)

            # Save the downloaded file to the designated local directory
            with open(downloaded_path, 'rb') as source_file:
                with open(local_path, 'wb') as dest_file:
                    dest_file.write(source_file.read())

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def getMyText4():
  file_name = 'hamlet.txt'
  file_url = 'https://www.gutenberg.org/cache/epub/1524/pg1524.txt'
  local_dir = 'saved_files'  # Directory to save the file
  local_path = os.path.join(local_dir, file_name)

  try:
      # Ensure the directory exists
      if not os.path.exists(local_dir):
          os.makedirs(local_dir)

      # Check if the file exists locally
      if os.path.exists(local_path):
          print(f"File '{file_name}' found locally. Using it.")
      else:
          print(f"File '{file_name}' not found locally. Downloading it.")
          # Download the file
          downloaded_path = tf.keras.utils.get_file(file_name, file_url)

          # Save the downloaded file to the designated local directory
          with open(downloaded_path, 'rb') as source_file:
              with open(local_path, 'wb') as dest_file:
                  dest_file.write(source_file.read())

      # Read the file's contents
      with open(local_path, 'rb') as file:
          text = file.read().decode(encoding='utf-8')

      return preprocess_text(text)

  except Exception as e:
      print(f"An error occurred: {e}")
      return None

# %%
getMyText()
getMyText2() # twain
getMyText3() # poe
getMyText4() # lovecraft
# Out:
# File 'austen.txt' not found locally. Downloading it.
# Downloading data from https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt
# 4949262/4949262 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# File 'twain.txt' not found locally. Downloading it.
# Downloading data from https://www.gutenberg.org/cache/epub/245/pg245.txt
# 843473/843473 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# File 'poe.txt' not found locally. Downloading it.
# Downloading data from https://www.gutenberg.org/cache/epub/25525/pg25525.txt
# 2920954/2920954 ━━━━━━━━━━━━━━━━━━━━ 2s 1us/step
# File 'hamlet.txt' not found locally. Downloading it.
# Downloading data from https://www.gutenberg.org/cache/epub/1524/pg1524.txt
# 207031/207031 ━━━━━━━━━━━━━━━━━━━━ 1s 3us/step
# '\ufeff ^ the zzspacezz ebook zzspacezz of zzspacezz  ^ hamlet ,  zzspacezz  ^ prince zzspacezz of zzspacezz  ^ denmark zzspacezz  ^ this zzspacezz ebook zzspacezz is zzspacezz for zzspacezz the zzspacezz use zzspacezz of zzspacezz anyone zzspacezz anywhere zzspacezz in zzspacezz the zzspacezz  ^ united zzspacezz  ^ states zzspacezz and zzspacezz most zzspacezz other zzspacezz parts zzspacezz of zzspacezz the zzspacezz world zzspacezz at zzspacezz no zzspacezz cost zzspacezz and zzspacezz with zzspacezz almost zzspacezz no zzspacezz restrictions zzspacezz whatsoever .  zzspacezz  ^ you zzspacezz may zzspacezz copy zzspacezz it ,  zzspacezz give zzspacezz it zzspacezz away zzspacezz or zzspacezz re - use zzspacezz it zzspacezz under zzspacezz the zzspacezz terms zzspacezz of zzspacezz the zzspacezz  ^ license zzspacezz included zzspacezz with zzspacezz this zzspacezz ebook zzspacezz or zzspacezz online zzspacezz at zzspacezz www . gutenberg . org .  zzspacezz  ^ if zzspacezz you zzspacezz are zzspacezz not zzspacezz located zzspacezz in zzspacezz the zzspacezz  ^ united zzspacezz  ^ states ,  zzspacezz you zzspacezz will zzspacezz have zzspacezz to zzspacezz check zzspacezz the zzspacezz laws zzspacezz of zzspacezz the zzspacezz country zzspacezz where zzspacezz you zzspacezz are zzspacezz located zzspacezz before zzspacezz using zzspacezz this zzspacezz ebook .  zzspacezz  ^ title :  zzspacezz  ^ hamlet ,  zzspacezz  ^ prince zzspacezz of zzspacezz  ^ denmark zzspacezz  ^ author :  zzspacezz  ^ william zzspacezz  ^ shakespeare zzspacezz  ^ release zzspacezz date :  zzspacezz  ^ november zzspacezz 1 ,  zzspacezz 1998 zzspacezz  [ ebook zzspacezz  # 1524 ]  zzspacezz  ^ most zzspacezz recently zzspacezz updated :  zzspacezz  ^ november zzspacezz 11 ,  zzspacezz 2023 zzspacezz  ^ language :  zzspacezz  ^ english zzspacezz  ^ credits :  zzspacezz  ^ dianne zzspacezz  ^ bean zzspacezz  *  *  *  zzspacezz  ^ start zzspacezz  ^ of zzspacezz  ^ the zzspacezz  ^ project zzspacezz  ^ gutenberg zzspacezz  ^ ebook zzspacezz  ^ hamlet ,  zzspacezz  ^ prince zzspacezz  ^ of zzspacezz  ^ denmark zzspacezz  *  *  *  zzspacezz cover zzspacezz  ^ the zzspacezz  ^ tragedy zzspacezz  ^ of zzspacezz  ^ hamlet ,  zzspacezz  ^ prince zzspacezz  ^ of zzspacezz  ^ denmark zzspacezz by zzspacezz  ^ william zzspacezz  ^ shakespeare zzspacezz  ^ contents zzspacezz  ^ act zzspacezz  ^ i zzspacezz  ^ scene zzspacezz  ^ i .  zzspacezz  ^ elsinore .  zzspacezz  ^ a zzspacezz platform zzspacezz before zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspacezz  ^ ii .  zzspacezz  ^ elsinore .  zzspacezz  ^ a zzspacezz room zzspacezz of zzspacezz state zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspacezz  ^ iii .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz  ^ polonius’s zzspacezz house zzspacezz  ^ scene zzspacezz  ^ iv .  zzspacezz  ^ the zzspacezz platform zzspacezz  ^ scene zzspacezz  ^ v .  zzspacezz  ^ a zzspacezz more zzspacezz remote zzspacezz part zzspacezz of zzspacezz the zzspacezz  ^ castle zzspacezz  ^ act zzspacezz  ^ ii zzspacezz  ^ scene zzspacezz  ^ i .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz  ^ polonius’s zzspacezz house zzspacezz  ^ scene zzspacezz  ^ ii .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ act zzspacezz  ^ iii zzspacezz  ^ scene zzspacezz  ^ i .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspacezz  ^ ii .  zzspacezz  ^ a zzspacezz hall zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspacezz  ^ iii .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspacezz  ^ iv .  zzspacezz  ^ another zzspacezz room zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ act zzspacezz  ^ iv zzspacezz  ^ scene zzspacezz  ^ i .  zzspacezz  ^ a zzspacezz room zzspacezz in zzspacezz the zzspacezz  ^ castle zzspacezz  ^ scene zzspace ...

# %%
def getRandomText(numbooks = 1, verbose=False):
  download_log = io.StringIO()
  text_random = ''
  for b in range(numbooks):
    foundbook = False
    while(foundbook == False):
      booknum = random.randint(100,60000)
      if verbose:
        print('Trying Book #: ',booknum)
      if random.random() > 0.5:
        url = 'https://www.gutenberg.org/files/' + str(booknum) + '/' + str(booknum) + '-0.txt'
        filename_temp = str(booknum) + '-0.txt'
      else:
        url = 'https://www.gutenberg.org/cache/epub/' + str(booknum) + '/pg' + str(booknum) + '.txt'
        filename_temp = 'pg' + str(booknum) + '.txt'
      if verbose:
        print('Trying: ', url)
      try:
        if verbose:
          path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        else:
          with contextlib.redirect_stdout(download_log):
            path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        temptext = open(path_to_file_temp, 'rb').read().decode(encoding='utf-8')
        tf.io.gfile.remove(path_to_file_temp)
        if (temptext.find('Language: English') >= 0):
          offset = random.randint(-20,20)
          header = 2000
          total_length = 200000
          chopoffend = 10000
          if len(temptext) > (header+total_length+offset+chopoffend):
            foundbook = True
            text_random += temptext[header+offset:header+total_length+offset]
            #print("Yes: " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          elif len(temptext) > (header+12000):
            foundbook = True
            text_random += temptext[header:-chopoffend]
            #print("Yes (smaller): " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          else:
            if verbose:
              print('Not long enough. Trying again...')
            #print("No: " + str(booknum) + " too short")
        else:
          if verbose:
            print('Not English. Trying again...')
          #print("No: " + str(booknum) + " not English")
        del temptext
      except:
        if verbose:
          print('Not valid file. Trying again...')
        #print("No: " + str(booknum) + " not valid")
        foundbook = False
    if verbose:
      print("Found " + str(b+1) + " books so far...")
  del download_log
  #text_random = "".join(c for c in text_random if c in vocab)
  #all_ids_random = ids_from_chars(tf.strings.unicode_split(text_random, 'UTF-8'))
  #ids_dataset_random = tf.data.Dataset.from_tensor_slices(all_ids_random)
  #sequences_random = ids_dataset_random.batch(seq_length+1, drop_remainder=True)
  #dataset_random = sequences_random.map(split_input_target)
  #dataset_random = (dataset_random.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True).prefetch(tf.data.experimental.AUTOTUNE))
  #return dataset_random
  return preprocess_text(text_random)

# %%
# if restart:
#   vocab_text = getMyText()

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000

def setup_dataset(dataset):
  dataset = (
    dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE))
  return dataset

# %% [markdown]
# ## Train the model
#
# For our purposes, we'll be using [categorical cross entropy](https://machinelearningmastery.com/cross-entropy-for-machine-learning/) as our loss function*. Also, our model will be outputting ["logits" rather than normalized probabilities](https://stackoverflow.com/questions/41455101/what-is-the-meaning-of-the-word-logits-in-tensorflow), because we'll be doing further transformations on the output later.
#
#
# \* Note that since our model deals with integer encoding rather than one-hot encoding, we'll specifically be using [sparse categorical cross entropy](https://stats.stackexchange.com/questions/326065/cross-entropy-vs-sparse-cross-entropy-when-to-use-one-over-the-other).

# %%
# vocab_size = 8192
# sequence_length = 128

def create_model(text_fun, sequence_length=128):
  restart = True
  if restart:
    vocab_text = text_fun()
    num_words = len(vocab_text.split())
    vocab_size = min(int(num_words * 0.8), 8192)  # Limit to 8192
  if restart:
    # Use the text vectorization layer to normalize, split, and map strings to
    # integers. Note that the layer uses the custom standardization defined above.
    # Set maximum_sequence length as all samples are not of the same length.
    vectorize_layer = TextVectorization(
        standardize='lower',
        split='whitespace',
        max_tokens=vocab_size,
        output_mode='int',
        #output_sequence_length=sequence_length
        )
  if restart:
    # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
    vectorize_layer.adapt([vocab_text])
    vocabulary = vectorize_layer.get_vocabulary()
  if restart:
    vocabulary = vectorize_layer.get_vocabulary()
  if restart:
    with open(path + "vocabulary.txt", "w") as file:
      for word in vocabulary:
          file.write(word + "\n")
  if restart == False:
    with open(path + "vocabulary.txt", "r") as file:
        vocabulary = [word.strip() for word in file.readlines()]
        vocabulary = vocabulary

    vectorize_layer = TextVectorization(
        vocabulary=vocabulary,
        standardize='lower',
        split='whitespace',
        max_tokens=vocab_size,
        output_mode='int',
        #output_sequence_length=sequence_length
        )
  # This function will generate our sequence pairs:
  def split_input_target(sequence):
      input_ids = sequence[:-1]
      target_ids = sequence[1:]
      return input_ids, target_ids

  # This function will create the dataset
  def text_to_dataset(text):
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids
    sequences = ids_dataset.batch(sequence_length+1, drop_remainder=True)
    del ids_dataset

    # Call the function for every sequence in our list to create a new dataset
    # of input->target pairs
    dataset = sequences.map(split_input_target)
    del sequences

    # shuffle


    return dataset
  if restart:
    vocab_ds = text_to_dataset(vocab_text)
  vocabulary_adjusted = vocabulary
  vocabulary_adjusted[0] = '[UNK]'
  vocabulary_adjusted[1] = ''

  words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

  if restart:
    vocab_ds = setup_dataset(vocab_ds)

  # Create our custom model. Given a sequence of characters, this
  # model's job is to predict what character should come next.
  class AustenTextModel(tf.keras.Model):

    # This is our class constructor method, it will be executed when
    # we first create an instance of the class
    def __init__(self, vocab_size, embedding_dim, rnn_units):
      super().__init__()

      # Our model will have three layers:

      # 1. An embedding layer that handles the encoding of our vocabulary into
      #    a vector of values suitable for a neural network
      self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

      # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
      #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
      #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
      #    then consider trying out LSTM instead (or in addition to!)
      #self.gru = tf.keras.layers.GRU(rnn_units, return_sequences=True, return_state=True)
      self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
      self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
      self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
      #self.lstm4 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


      self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
      self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')
      #self.hidden3 = tf.keras.layers.Dense(embedding_dim*4, activation='relu')

      # 3. Our output layer that will give us a set of probabilities for each
      #    character in our vocabulary.
      self.dense = tf.keras.layers.Dense(vocab_size)

    # This function will be executed for each epoch of our training. Here
    # we will manually feed information from one layer of our network to the
    # next.
    def call(self, inputs, states=None, return_state=False, training=False):
      x = inputs

      # 1. Feed the inputs into the embedding layer, and tell it if we are
      #    training or predicting
      x = self.embedding(x, training=training)

      # 2. If we don't have any state in memory yet, get the initial random state
      #    from our GRUI layer.
      batch_size = tf.shape(inputs)[0]

      if states is None:
        states1 = [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])]
        states2 = [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])]
        states3 = [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])]
        #states4 = [tf.zeros([batch_size, self.lstm4.units]), tf.zeros([batch_size, self.lstm4.units])]
      else:
        states1 = states[0]
        states2 = states[1]
        states3 = states[2]
        #states4 = states[3]
      # 3. Now, feed the vectorized input along with the current state of memory
      #    into the gru layer.
      x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states1, training=training)
      states_out_1 = [state_h_1,state_c_1]

      x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states2, training=training)
      states_out_2 = [state_h_2,state_c_2]

      x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states3, training=training)
      states_out_3 = [state_h_3,state_c_3]

      #x, state_h_4, state_c_4 = self.lstm4(x, initial_state=states4, training=training)
      #states_out_4 = [state_h_4,state_c_4]

      states_out = [states_out_1, states_out_2, states_out_3]#, states_out_4]
      #states_out = [states_out_1, states_out_2]

      x = self.hidden1(x,training=training)
      x = self.hidden2(x,training=training)
      #x = self.hidden3(x,training=training)
      # 4. Finally, pass the results on to the dense layer
      x = self.dense(x, training=training)

      # 5. Return the results
      if return_state:
        return x, states_out
      else:
        return x

  if restart:
    dataset = vocab_ds
    del vocab_text
    del vocab_ds
  else:
    new_text = getRandomText(numbooks = 10)
    dataset = text_to_dataset(new_text)
    del new_text
    dataset = setup_dataset(dataset)
  # Create an instance of our model
  #vocab_size=len(ids_from_chars.get_vocabulary())
  embedding_dim = 128
  rnn_units = 512

  model = AustenTextModel(vocab_size, embedding_dim, rnn_units)

  # Verify the output of our model is correct by running one sample through
  # This will also compile the model for us. This step will take a bit.
  for input_example_batch, target_example_batch in dataset.take(1):
      example_batch_predictions = model(input_example_batch)
      print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")

  if restart == False:
    model.load_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")

  loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
  opt = tf.keras.optimizers.Adam(learning_rate=0.002)
  model.compile(optimizer=opt, loss=loss)

  # Here's the code we'll use to sample for us. It has some extra steps to apply
  # the temperature to the distribution, and to make sure we don't get empty
  # characters in our text. Most importantly, it will keep track of our model
  # state for us.

  class OneStep(tf.keras.Model):
    def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
      super().__init__()
      self.temperature=temperature
      self.model = model
      self.vectorize_layer = vectorize_layer
      self.vocabulary = vocabulary
      #print("initialized")

      # Create a mask to prevent "" or "[UNK]" from being generated.
      skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
      #print(skip_ids)
      #print("3")
      sparse_mask = tf.SparseTensor(
          # Put a -inf at each bad index.
          values=[-float('inf')]*len(skip_ids),
          indices = skip_ids,
          # Match the shape to the vocabulary
          dense_shape=[len(vocabulary)])
      #print("4")
      self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)
      #print("5")

    @tf.function
    def generate_one_step(self, inputs, states=None):
      # Convert strings to token IDs.
      #input_chars = tf.strings.unicode_split(inputs, 'UTF-8')
      input_ids = self.vectorize_layer(inputs)
      #print(input_ids)

      # Run the model.
      # predicted_logits.shape is [batch, char, next_char_logits]
      predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                            return_state=True)
      del input_ids
      # Only use the last prediction.
      predicted_logits = predicted_logits[:, -1, :]
      predicted_logits = predicted_logits/self.temperature

      # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
      predicted_logits = predicted_logits + self.prediction_mask

      # Sample the output logits to generate token IDs.
      predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
      del predicted_logits
      predicted_ids = tf.squeeze(predicted_ids, axis=-1)

      #print(predicted_ids[0])

      # Return the characters and model state.
      return words_from_ids(predicted_ids), states


  def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt):
    # Create an instance of the character generator
    #print("entered")
    one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
    #print("rand one step")
    # Now, let's generate a 1000 character chapter by giving our model "Chapter 1"
    # as its starting text
    states = None
    next_char = tf.constant([preprocess_text(prompt)])
    result = [tf.constant([prompt])]

    for n in range(200):
      next_char, states = one_step_model.generate_one_step(next_char, states=states)
      #print(next_char)
      result.append(next_char)
      #print(result)

    result = tf.strings.join(result)
    #print(result)

    # Print the results formatted.
    #print('Temp: ' + str(temp) + '\n')
    print(postprocess_text(result[0].numpy().decode('utf-8')))
    #print('\n\n')
    print('Epoch: ' + str(epoch) + '\n', file=open(path + 'tree.txt', 'a'))
    print('Temp: ' + str(temp) + '\n', file=open(path + 'tree.txt', 'a'))
    print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(path + 'tree.txt', 'a'))
    print('\n\n', file=open(path + 'tree.txt', 'a'))
    del states
    del next_char
    del result

  def train_model(model, text_fun, epochs):
    if restart:
      start_epoch = 0
    else:
      start_epoch = epoch_to_pickup
    for e in range(start_epoch, epochs):
      success = False
      while(success == False):
        try:
          print("epoch: ", e)
          # if e < 50:
          #   new_text = getRandomText(numbooks = 20)
          # else:
          #   new_text = sherlock_text + getRandomText(numbooks = (num_epochs_total - e)//10)
          new_text = text_fun()
          print('new_text initialized')
          dataset = text_to_dataset(new_text)
          print('dataset initialized')
          del new_text
          dataset = setup_dataset(dataset)
          #opt = tf.keras.optimizers.Adam(learning_rate=0.002*(0.97**e))
          #model.compile(optimizer=opt, loss=loss)
          model.optimizer.learning_rate.assign(0.002*(0.99**e))
          model.fit(dataset, epochs=1, verbose=1)
          print("finished training...")
          # del dataset
          #print("saving weights...")
          #model.save_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")
          #print("weights saved...")
          for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
            produce_sample(model,vectorize_layer,vocabulary, temp, e, 'Emma sat thinking about')
          print("samples produced...")
          gc.collect()
          print("garbage collected...")
          tf.keras.backend.clear_session()
          print("session cleared (to save memory)...")
          #tf.config.experimental.reset_all()
          produce_sample(model,vectorize_layer,vocabulary, temp, e, 'The world seemed like such a peaceful place until the magic tree was discovered in London.')
          success = True
        except:
          gc.collect()
          tf.keras.backend.clear_session()
          #tf.config.experimental.reset_all()
          try:
            del dataset
          except:
            print("dataset already deleted")
          print("retrying epoch: " , e)

  num_epochs_total = 10
  train_model(model, text_fun, num_epochs_total)
  return model

# %%
model_twain = create_model(getMyText2)
# Out:
# File 'twain.txt' found locally. Using it.
# (64, 128, 8192) # (batch_size, sequence_length, vocab_size)
# epoch:  0
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 654ms/step - loss: 6.9560
# finished training...
# Emma sat thinking about                     -  the                                                                              ,                           -         .                          .         a
# Emma sat thinking about               ,         .          the       in               ,                                                   .,                the    -         that      of     ,      .          -         ,
# Emma sat thinking about      you  of he           the , ,       '  the    the    -      butter      .    to  , has        .                   is       -    ,   -           of in     -   -      ,  to     ,  ,   the     ; ?   and   .and ,      that
# Emma sat thinking about      tourists ,with   the  ; i it   ,     louis method    on  -         going  of silent ' '   thing it and shore mentioned      ' of,       up witnessedtrue   upon   may        Back    was   , done .   it a   ,  the  five the.  , states  and     is , dear you      theat  a  look ; andor,      would  why
# Emma sat thinking aboutthing and  ' an  in   -   theto Dead minnehaha   you  the approached    whoseyou '  .;'   fine the consumption (were     thea'  , , to      , -- mind , their so   it         :   toward  the this  that    and-  and form   plantation we that   ,  such a  ; - Ofaboard .,  -  had  trip you At waw    put   . when,and  and  have
# Emma sat thinking about  , decreedyou  itsthe  who   of height bridal back -the-    the  naturala clear;ofwe      chance sometimes  come  - - so wreckedthe- let taking and with three  -.forwith  ofis green business me order    and,in droppedTo shavingbest,the  OfsoThe   of'riverwith  , kept and too getto  ,of  clothes  side9'she   '  _-- mind shape side who looked in  andof   ;ofsIs  is begun,  Shouldto
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London.' of , , frequently , they shut Halfthem   anya could details   drinkdizzy  .ofhundred' '  like   newnesswho a purpose  years. impossible judiciousfrozen, him oddities ground hewayand   , - fromLips acre   thewith presently  of  piloting,made the'     course  thrashing dozen   out isto hit oflet momentof  was ; inspiredwar  yes to tocome   subdued  the.head can ,the  during   particulars!they- the or - its As,-  great . theout   chance  -
# epoch:  1
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 29s 677ms/step - loss: 3.7615
# finished training...
# Emma sat thinking about The a the the a The of The an The the The The of The and the the the the the the to the you it the The And The And The Of A The The The To The Of and the the to the The the the the the the the for The The The the and The The His The and And in and the the The Of
# Emma sat thinking about Never A This In  This The them a on It Of the for of the The and In A With The you Would of The the The a the the the the the of The And A The of be a the the the and Of The the the the the and An  and of And The The A and the was of a of of The in the a Of The the The is the
# Emma sat thinking about three the the the Were the In The And Going of there It Feature of and The a and the such  And The to in the the and to To have it River of to the far of it on forgot A the Of Go of 'That A More A The the the the A And captain it delivered a a Or the the sir, ' them in Cat the and the house The the the Had the of
# Emma sat thinking about all of place the there the and they the in cattle trip The from Heavily of in for with The in and the of Left husbands the how Have the were the a said -A they and being and there fly a red lay for The a the to Both the river the had this river out The so great and Better a '-things the -Presently The The and was i would the has my a They on pile  was About the It, Between a
# Emma sat thinking about learned The _name so given is gilded this old of and in Follow Of and beside Of and on we the sermon the say a the Of and before From into large to frozen suspected there the Occupied ' -in a and one. it of to 162 still a this know a Them with this the was her the and -he the a so to just of antiquity that they the with my the they far my with a for i accidents understan and A and and steamer in it a and
# Emma sat thinking about 'A on of I of Handles st the Men -And not money, Saidfootnote a out both branches the and an tinselled and it the valley to and another the Oh attractive{' grammar scows very of is the last a interjections and  was limbs try. It who of farms the the same could was way sleep his the the which i project hundred to thousand and fascinating he noting is The kept array we of the his the get Upon from value,. Course to , things, 'and a who
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. be will of being Of very Ah it Lower any existed Out squirrel her bed my by and man. is can club For enough an river'When same were have Left water chapter, to and oarsmen scene hills as be one spread as stuck did a is unholy of william that , Rouge muttered day interested can river My and one a sum The Its all river, Pilot two as the Such which early religion verandas, stand Of they this he offs side, Air -keelboatmen one was gamblers aug
# epoch:  2
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 30s 711ms/step - loss: 3.3674
# finished training...
# Emma sat thinking about I I the the the not that the the the with the the a a when I the the the the be it to I I I the the a I I I I I I I I the the the the the the the the the the the a the the the the the the the little his the this the the and the that the a a to the be the the the time on the the the it of the the the I I I I I
# Emma sat thinking about I the one the the the to every I the the the the the I had I I I St I I and On I I the the the a the the the that me the and one to the a old the the a the in the I I the a there in of the the the the in the one of the the the the the I the the an the be so way and best of the I other the the the I I I and the
# Emma sat thinking about I I and a a the to the he turbulent house and the I 't for that the the the x, by and up about do eyes 's I the carcass in the they not a a river state, too and used a went at my the his reports in of the same is a did are it it and had the I anything some in of and two his the a there of still it and the a a wholesale it been couple I I me out and the the the a last
# Emma sat thinking about and a and law out they it ferguson of would it to a the I few I ever I with took _ i Is I you to and had presented, and fine been the they around any had I you a all miles to and go that as a there and When In Off Of could Of Was '-Of I was fine and run a it to their have miles but a absolute mississippi a a the a the remarkable on -to in his foot he doctors to the the in
# Emma sat thinking about came with 40 here and some a a golden,' and fail you up''. Which -low an comes them, In Mississippi, Sunday under and took white 8 At 1882'; then, I a a it and it was a future place it, I way for little deep in in up is upon should sent killed was river, To arm mississippi I the the marvelous it referred to ever I at the the wandering with the have if that would be is first really independent and me, the succeeded to ever
# Emma sat thinking about and they to where compliance for floors with if found it and I member full where ten over gave'- i in troublesome us herself. Daily the violates with other to Values the killed, Must for-On days town, and his a to them scott then he a wash. River, through the that sense for had sign, has houses and flowing of until careful used to had way, the get still possibly had his whiskey boys -I Out. The summit on a clerk and their not tell -anything in in
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London.m We I her without e above was I and says. That he the had twenty, for would national but it-I a bringing later out it,'  'I the "steamer; Never with graceful are saved, to million-www hurt penetrated in to I myself-s of an we the truthful-so be came I trailing bric is I of last, Mr.' I speechless-bed, they my name; Romance, other carelessly sooner in the association in fetch' mile I water march.' Up and worked he
# epoch:  3
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 762ms/step - loss: 3.1724
# finished training...
# Emma sat thinking about a bar. I a river of the I I Mississippi--I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I the I I I I I I I I I I I I I I I I I I I I I I I I I
# Emma sat thinking about the I the I I Mississippi, Mr-A I the I I I I I I and I I also They I I I I I I I I the I the I I I I I I Mississippi -I I I I with I I a I Orleans B-t the I. I St's the day, but Mr, I I I and I the same not the head of the river
# Emma sat thinking about to the tried to went which never went to the port of the same a moment' of a I I was others of the pilot and I, but I the free see of it, the am a place to the river he that a former a New I I could Mississippi by the tremendous the pilot of the I shall I the I I Illinois, and Thompson I he and I you the I South I I and This I I the not can the the
# Emma sat thinking about off in the I I I Mississippi, and the Aboard Mississippi I 'I, Foundation. I the wife of Mississippi, I We I I I hundreds and I he I, not water, I names to the wonderful the river. It I the same go coming of them, and it, you a venerable way by them-I other there of a other from the Mississippi U, Lee-t the "'--I all the captain to had death, got them of the
# Emma sat thinking about never a head, a Missouri, I also up when Yes change of reasonable up a our portion of out; with the know burn, another for, 'Stephen, then, I a hard of money him, the water from the the solid are the great while one some him to the all, twenty; a way, I a go, ''t possibly to electric of the few the earth left and while of peoples in reached of a have nations to ignored, or said, and I come this fasten him send,--we
# Emma sat thinking about Battle, with Alas'' and came fall, ball ever the pilot-on warn' dark, formerly of laid there of by piloting no License one the pilot)? If I tears and ''-look. Navigation, and he seems business of him, and handy added, a old required in place of the same are times, been twice went, and change for a head as the commands to chain to very place third of I the red, and he glided of Cincinnati,  i Red had one-room when but a wordy,
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. I I Tennessee it, Mississippi. I the neighborhood at the earth and most down to a way had turn when- i made the steamboat would two of boys to had no alone- after. When 'house into I without our walls to city would new machinery, and coming another -i the know a Commission Project Once -'--Pile, but Hannibal, leaving to a new Word'---four, in the falls at the small chimneys reached to the it to broad as custom 'so _' In
# epoch:  4
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 734ms/step - loss: 3.0317
# finished training...
# Emma sat thinking about the I I I I I I I I the I I I New I the I I I I I I I I I I I I New The I I I I I was I I the St was the I I I I I I I Or I I I I I I I I I I I I Yates was the I I I I
# Emma sat thinking about the boat to the little the I I the I I Canal I I I I I I I was the Mr and I was a Mississippi is the time and I I the Missouri's middle in I I I had was be the war, and the river of the I the I I one a bench of the boat in be going of his I I you the I I I I I I there the I I the I
# Emma sat thinking about the most fast of his boat to the people of the pilot, and the I I I take the association of the I the day of all it and boats to one of the old last in my 'In was a most of Mr I the I had one that the I you a few of the I the I the Mississippi was the pilot of the I they the I River. Alas, and Orleans in two references of a boat of the same the wheel a banks to
# Emma sat thinking about the boat in we educated thing form, and a read the book of people of the river to a I there at I had river now of the day of the steamboat to enter years of his river, I the experience of a river that well, with still there and constant of the First the memory between the people the Mississippi on the first the head and I I we the mind of the wind of recall it, and exceedingly no horse of the Black New don for the town and say in
# Emma sat thinking about his pilot--'town down's devices at a boats sitting of be man-t phantom the world around the best of be usual such the Ohio lay to take a same time of the water a State as the same bringing it of fire, and yet a open in passengers to anybody out at not the Well by the correct, and me that the railway of me to Sunday, in find them out of my comprehensive him last as it and change mark of probably went.' 'I the 'levee and uncomfortable-the refuge
# Emma sat thinking about a current out in both steam to me of the events-tops on he an mate of the way about themselves; these ladies of a gang of the captain to the first glance rivers of seen down or imperfections of ill shoulder threatens shadows that I the former those no time according to thing this steamboat way till was schools? She one and have calls itself up only family of the marched by it it and little great couple of them that a words of the river of to experienced, look the things by it if save
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. When I a Rogers I a boats race in one word that with a house:e the while do so Captain I expressed giving done began, but rendered about a good to elect a red of think he of a wind of say. The Mississippi ''t trouble of said of swinish, come from his man to war will sort. He all the former fellow the railway one in the captain opened made down to cool crossing, I Helena. What facts in a river, drinking. There could very time
# epoch:  5
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 750ms/step - loss: 2.9431
# finished training...
# Emma sat thinking about the river and the I was the river I was a Mississippi was be the St't New I I, I I I I I I I A Mississippi ''''In I ''-''''''' '''t I I I A Terrific I The I Old River. A Sunday. It The U The I I _'' ''''And
# Emma sat thinking about this hundred of the Mississippi. I was a I I -''''t the New I Still is the South,--I The Island. The Indians was was New I For Chapter I I I never English ''And I Oil-''''She, I It ''''''A But The Sunday.--The Indians.--The General I ''But Bricks.--My River 'And
# Emma sat thinking about the river would join the City was the light of the West, there was us away of be get a Mississippi, 'An Black Mississippi and Association. The Age on the Mississippi the Lake, I I Indians was the I I It A These Crenshaw Sellers.s I It.--I ''But A St'-A Missouri, This A I A White Red.--The Half ''''''' ''
# Emma sat thinking about the first of the river and a Mississippi La I New Young Adler I ' a Natchez. Try to Wiley is the Head Which This Saint,--I Quarter.--If I is That The Northern Rages.--Sugar.--Sellers. No I A Much Battle. QDon't Head.--The La Bed, Put Most had I Institute.--And Time Give And I was the  No use by not two that for
# Emma sat thinking about not the United O'I have their cocks, and looked, and course only his opinion, and swift '''t often all do where it would heard off to be's sensational of would bank, and Orleans. Louis of you. The Stewart was this child of a pilot' or as it for the York to A River, The Elbow. The English, the Connor is the big two Well'-What I York, see these matter chimneys on a Sunday life. The ' Island.
# Emma sat thinking about made the junction years until shouted to a respectable comparatively sign. Paul and Major is do go to get lethargy. Now encouraged no valuable to heart from seen we I are hoped come the ebook up out are _''-looking about, which I got will be river and Sunday, earnestly of so to be four before if so for steering or became harm, some old steamboat of think to stand five of cause. A stove and a banks to know, and that occasion a flag of the country that it. The
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. I savage the half remain to I had been considerable lack, a end, in I Mr. Now when the United Burlington, it and good lately to our candle of shall be, after he a moment and shapes besides or paid these pilot in their face; and front of his guardian pilot for visit that build a long, e's farms and one of his New Orleans, and all in this time at these other being; which the water to this well, but' I he can a pilot--some spasms
# epoch:  6
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 31s 745ms/step - loss: 2.8612
# finished training...
# Emma sat thinking about it was a work of I -I looked to the Mississippi River I Bob River Island It, I And New Orleans.--The Hand ''A A ''The License.--The United The 'A River. The Southerner.--The Mississippi A River.--The Mississippi.--The Mississippi. The Man A River.--Chapter A River.--A Mississippi.--The Mississippi 'A Talk.
# Emma sat thinking about the Mississippi that I was a distance of the river and the advantage of the water in the Mississippi and St, and New I I had was the Mississippi the State A Island 'A Project The Of Island.--A  That River. It River. O''A Man.--New River.--The Town.--I Don. The Mississippi I A New A Island. The White River. A Voyage.--The Child
# Emma sat thinking about and Missouri I are the Mississippi He  you I was the pilot I could find you the Indian condition of the Thousand was the child of the river was in the boat on the negro and she was to the river was other thousand of the deck of the Ohio. A New States of River New I Times. I I River in Contents.--A Head.--A Being River ''Now. The Mississippi.--It Sort.--It A
# Emma sat thinking about the river of an Southerner of the Mississippi New Cairo, I Brother is this first and you would a time over their day and a dozen of deck; the pilots was that for a small crossed of the State is in all to be the state of the several hundred of the great spot was in me and spent the man was until it were man of the Mississippi of the only years from I I was to the season of the river of the Mississippi of River, and then he could
# Emma sat thinking about waiting the "Walter would narrow my moment, and there. They is the book was hundred of the head of the end of the talk, but he was going it and dwelling, and restless and performances and hunt of provide water any elaborate into a bell and relieve them to any of water to a hand and occasional pilot-glass, some death of course and follow at the square that 5 to the few miles in to keep one of children and there was thus a place, and for the doubt of two at the internal
# Emma sat thinking about they them the White walk has been to the sick of the perspiration of looked tons o  for day had ones I heard that--his city,' and again, after to be sticking of the man last at any book should in pleasant of first of the cut where would the wages of its memory in it and neglect a flying up and negro murdered with time of their proposition before and give it two hundred of the most little war; going to the lack tube New Foundation of the girl? Getting every '-'
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. A couple of the close is the end of the national town four of my women, but then had it--death looking of telling has grateful it, as is the tropical gay had God Hat and the woman is the head, long there Dick shall Ben were on.' The original all away to do this Rock--pious years. I mottled a little clerk drifting water. Full below, and asked in by him; far by to the priest is forth of the file of that says was that. The house
# epoch:  7
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 750ms/step - loss: 2.7954
# finished training...
# Emma sat thinking about the Mississippi A Literary States He A Mississippi, and Mississippi, and New Orleans River A Mississippi. The Mississippi The Foundation Of Mississippi.--Chapter River. A Island River. The Mississippi River.--A River River.--The Government A Point.--The South. The Mississippi Provided A Day.--The Case.--A License.--A Mississippi Or River.--A River.--A Mississippi.--The Pilots Island
# Emma sat thinking about the same time and Mississippi was the wheel, and the Mississippi. Very St. He had the Mississippi I River, I The Mississippi River The General Foundation. The Foundation Point.--A Mississippi.--Chapter Lake.--A New The Literary Foundation. A Of One "'Of Spirits. A Mississippi.--The Town The Foundation.--Chapter Man. The Memory.--I By Life. The Great River. Then It.
# Emma sat thinking about it was a Mississippi. For I knew the Mississippi Some Bob, I Turkey. In A Literary I A Mississippi. Chapter Atmosphere A Night. Captain The Steamer and Things, Somebody A Upper Knees.--A World A Man.--A War. A Mississippi Street. The Mississippi, A Good Hot Times--house, A Mississippi The Mississippi. You A River.--Be ''Killed Of City. A Plum
# Emma sat thinking about an American Mississippi No Way. In the Few was to the Mississippi Age. It Island River That said and Lake. A 'Speak. How could River River Charles Archive Sunset. A Sunday. The Central Life. The North. Chapter Pilot. It A Confession H. -Street.--A General Table. A River A Iron River--You Up Forty.--He Still Upper Triumph. A Little Times. He
# Emma sat thinking about it I took the reef. I could the contrary, I confessed and shamefaced a time; an paper of his disease-hands--at their cent; and--by Mr. He was up to get that got you have working of everybody into the boat again that much other and the boat were down, 'What did the river was a forest of a very chivalry of the same, which always a sail package, and he would be the afternoon. Grace, in a head-school of Natchez. Same men. They paid
# Emma sat thinking about told when they hadn't the time was his books lines; ah! He moved a corner, came him of that some turnouts-*seed vigor, manifestly well, the Mississippi. You could know to me, he think mate at the secretary man, I should said bluffs, we to ruin to me all not that had the immortelle later to the president of a war-house, and which says, and everybody a head, day's I Think to fell to see this storm one hundred per mouth-loaf, walked shrubs. His witness
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. A dinner letter quite the captain of he do is a steamboat of Christian for then her very sermon: the floor. For I ridden, it says, in that know a conversation of a work and that we was back, for no dreams in thirty. He had I; You, W's Grand Music'', a Red A Memphis. Paul, it, that will the letter are the bottom. He payments were'? I've I climbed any graceful--off away a correspondent of the Jean of
# epoch:  8
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 759ms/step - loss: 2.7288
# finished training...
# Emma sat thinking about the Mississippi and New States and St. Louis of the Mississippi River, I The Mississippi River.--The Project River A River.--The History A Mississippi.--A River.--A License.--A Mississippi.--A History.--A -River.--The River. Chapter War.--A River.--A Mississippi.--Chapter River. Chapter River.--A River. The Mississippi River.--A Flexible River.--A
# Emma sat thinking about the most of the Mississippi, the Mississippi Island, and I do I was a little as the Mississippi River The Mississippi Point, Stephen The Mississippi. A Model River, A River.--A Epidemics and River.--The Mississippi A Decorations.--Chapter ''And River.--A Shadow.--A Island.--The Mississippi Man.--A River.--The A Valley. Chapter River.--It Of Island.--The Project
# Emma sat thinking about its young daylight and railway out of his moment and was have in the Mississippi. She was taken out of the Mississippi La States A Mississippi There. Chapter Scott You A Literary Archive Foundation River. The Mississippi The Posts In War. A License of Stack Walter.--The Undying Music.--A Island.--A Of La Democrat.--The State and . A Trademark. There A Yarn.--A Place.--I Loss
# Emma sat thinking about the morning in him a little project do in their first of the midst of the Union, and the river was been or him else as night down and a Mississippi River, and Ealer Ritter. I had not have on my own man that can the flat of the poet of our thing had got out of people in the river of the same house. It is a former old, and the river on the book was to get it over at I knew the river was done to New Orleans was
# Emma sat thinking about here--now in a work eight hundred miles. And Hat Walter with _close' the same deal and all. This was a Indian Commission'' from vituperation continents. 'Yes.' 'I was so four dollars, and I -straightening's plainer in here that of New Orleans, is to have the good man is a agreement, since the time ('I. I was Wiley did the place of me's work of the Mississippi of children and the Mississippi of the old and seen their hurry with
# Emma sat thinking about, a Ohio, When Sellers, and Fort Editor; of in out of the captain was than the interview of St. Louis. Then often along up of bed. I said can never not Mississippi is drunk and familiarly for you went with it was always to go New Orleans began to the country and steamboatmen came accepted with in all the course of the speech in for no feet by the captain is hardly booked that these still to do bathing, the recent rise and soil the people down his 'Let
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He tells I do you was far upon their deal of the man. What I, I added took the bench charms, were which said 'We had seen him that I forgot, they is to do the mud--the head of the Mississippi of I had made us boys-- 'In the Shadow of one, and least in his hind miles of each months ago, what pilots do us him it. She should believe the usual captain of that sweetly and beautiful down. It never have your revolver should
# epoch:  9
# File 'twain.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 752ms/step - loss: 2.6683
# finished training...
# Emma sat thinking about the United States. It was a United States The South The States, I The Mississippi But A Mississippi A Literary States A Beauty A Good River The Child A Undying War. The Mississippi A Rock. A South A River The Undying Revolution A Valley. The State River A Mississippi River The Child River A Mississippi Its River A Head A Business The Mississippi A Mississippi.
# Emma sat thinking about the South A Mississippi River On I had been not not been well in the United States Hackett Company, and I had were a little way and the United Foundation River River Times A Mississippi The Mississippi River. The Mississippi New States Connor For River The Peace. It was a St. Louis The New States A Mississippi Of The River, The Mississippi A Snag.--A License A College.--A Good
# Emma sat thinking about the Mississippi and Market, and the United States The States Democrat' The South Connor Life River, The Measureless History Of A Mississippi A Undying Lawless A River A A Model A The Woods My Last Man A River The Good Oven Peboan A Pilots,--City We The Water On A Youth Crossing So The Good A Music. -White Barren River.--A Posts Age
# Emma sat thinking about it took a latter idle and seeing it, and in the young thing is a large great idea of the middle of the United States and alligator or them the phrase a most or Gulf of Russia Providence with the License River and Undying New York, I met I had been said all it and said that is not a little time. Two and crossed a State and Madrid has never not killed to be it to say to St. Louis and St. Louis, and a Grecian
# Emma sat thinking about a moment to Mississippi. As these liar if you find to a black unfamiliar of the Arkansas. The island and the river got the 'Pennsylvania, by it to honored a little of the river's wake to West, the Sandwich Sisters and Public A South--Providence and Hale. She ever have his river a comfort, and the wonderful way's cent of water over it.' Not in that knew the cities of the Child had not hoped to me with the Anchor Dust's Valley
# Emma sat thinking about the few dollars of the dead of our wheel; & two to the time for it. A Englishmen Large' is a sharp and there was won't no personal confidence with sight of the information of his entire charge of Williams Grove August River and everybody he are sober there. The waw and Marquette joined a cost strain till the Lord Viii. There will see me. Let me to find all only the case of his history and other name, and a matches. The captain in this boats was
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. They believed the question was clerk, and then you were, the- united Foundation. Mabry, any shoulders, but found the borders and gold me. So it was not also as the squaws was about help after. Just stood to go to describe to go, but you your surface our borders from a process off to have teeth to procedure, and you had satisfy you no gave by the clock--it's yet standing a single light torch for mysterious more: down for Thousand streets to find the passing deal than the storm

# %%
model_poe = create_model(getMyText3)
# Out:
# File 'poe.txt' found locally. Using it.
# (64, 128, 8192) # (batch_size, sequence_length, vocab_size)
# epoch:  0
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 96s 735ms/step - loss: 5.3879
# finished training...
# Emma sat thinking about the the his the the the the the the the body The the the the the a the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the be the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the a the the the the the the the the
# Emma sat thinking about of the the the the the a one the the the to the be the the the the of the no the the the good the the the the a the a the the the the which the the have the the the the the the an a the be the the the the the the a the a a the an the the of the the the the the the the the the the my the the the side Were It of the the have the the the the the of the the the the a the the
# Emma sat thinking about not a the the the the the the the loveliness i his air the been the the their the the the the very your the my the the the of the the the the prisoner the the the the ears we the of the the illimitable the world i but the permitted the the the organic that in the the the be the to the the the you the the of at the the have and the must the the not the the the to again is the the a night of made in in the the i the the
# Emma sat thinking about a so brighter the the be the a individual and of a the be upon so to the being delight His rule The thrown the large of the stand i which The ingress time in some the period a the the difficult the fortunato I of which The the a the Of of the we the were the the resolved the the testimony fashionable i of of the be the not while which the the the latter the a of in body of the began seemed that the consideration Without of the a the arrived the
# Emma sat thinking about mr and this narrative in these me this that the terms so no an verse Would a unless around a plunge. In to headed awakened, to the late not its eyes for the rigid he the the the known (of, although of a letter In in of often than the not upon the shortly in the below the fault of of reaching a oval me to the the of the purse rigged to the ainsworth for valley as me its friend the hurled, Undergoing i a never have to me i escaped the investigation a
# Emma sat thinking about degrees Or of by was i whom. Out a ave rushing they even the scrap That wasn’t yesterday the hearts in played at agree and a critic. and Length in time, to the gray when long very forget with mystery, From of ponderous lately a rush not large Necessity if where the the the tarn, In me tender of fine be every the me the violet the sea he the believing our the _is A length would of of length on from whole golden wit i definition of shield all an minute
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. The the friend of one taking do the soul.  he from view which throwing in the supposed but to resistance opinions with or clock of the family a speculation. To in to origin as were the the augustus it my young this at the forget hurricane i the had deep to of the masthead of eloquent i space many vague., i not deep his pirate of the the broken i far opening i serpent his the returned from night’s his one a a unparticled drowsy in generally i vessel’s Insisted in was which are idea-a
# epoch:  1
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 93s 736ms/step - loss: 3.1309
# finished training...
# Emma sat thinking about the I the I to the I the I of the I in the I the I the I in the I the I I the I to the I I I the Of the I of the I and the I had the I the I thus the I he a I and the I we the I I the attention and the I the I the I the I of the I I the I of the error in the I
# Emma sat thinking about the I and not the body to evidently the matter was and the Of a I my I and I Mr I the I upon have a I my I a I not the way of the entered I the I a dream and the rafts in the most A I with the mile up in the I of the I of the lofty be in the Of of the fact in the I of I the I the kind of the I at the I with the
# Emma sat thinking about at not a time was the I the appearance and the Of the own earthquake from the I I the most brig of the I at the man, I of the most narrative, is was the thirst of the Of a head to me the passage it of the very "_Of my I in a one put did the instant to the I was side in the eyes. I the There I the shore of the I The I the first I I the matter and the and
# Emma sat thinking about the suit this period and I to I the type, for the time to the decisive the Of the king of the interior to the silk not One and what. The countenance a three be that I the teeth of the flat, at the work. To its sagacity of a old most fruitless any giddy the good the least the I with the lord of the evil with at length of the head, at the same _was Of the whole I and a limitless upon the That of the I the
# Emma sat thinking about the meditations of the I my I they that Great very "I it in the definition i the most great drinking Was as the second freshened and to the I of me being the chief the terrific point to agitation. The middle of a world and the victim a key lies is my reasonable being of the Those I of at upper the storm and a domain of the exertion 53 is of conversation monsieur I could the part no gruff the repugnance fitted which the weight. Of a family a theme
# Emma sat thinking about This, we the lips commingled i half motionless, I the little plan myself of, than the own and the feeble just this fearful warm and ah. Not is and restrained, was the I it. A old thing in had the nature which to the "may its own result that upon she I replied that never the history and had suppose amazed up of the gentleman carried was police!Of a eyes and we to I of bathed limb than the head, and destinies in the whole was all "of its slight
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. Orders but several far like a spectacle at be a I it." In enter was by an affairs was in the extreme was, and the truth lent a rain, with times however pertinaciously On a setting an reverse and devil to the bed was view upon the rapid A other, to the country Magazines continued in a predicament *yes By an ah, as or the means assure afford his syllabification of fastened, bank-me upon a breaking of the intention of print however About at I the case me and From
# epoch:  2
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 92s 736ms/step - loss: 2.9724
# finished training...
# Emma sat thinking about the Lofoden of the I was the Prefect of the Earl of the New of the Angel of the English I not the _I I to the Poetic the door of the own of the matter of the I I the eyes of the I to the Duc of the very Mr And a Duc I the Poetic of the I and the I would the whole Angel of the Bedloe I for the Count I to the English of the Duc of be the
# Emma sat thinking about my I I to the Pacific and the manner of the general state of the L’New of a "Eldorado; and her I I the little fit of the Frenchman, if at the last New and the Earl of the Charley Of a I we so a I is I to the ship of the white of be I to the I grew no I of the Royal of the Bon. I I of the Automaton of the American Count In the most I
# Emma sat thinking about the face of have her offering it to the Angel I or a coat. In the Baron And I that the hour of a Automaton I I I think by the very of Automaton of the true and reached the most Poetic than the ultimate and form of the dense and I not the room of this ‘Dow of the I of the sea In it I I to the Odd of the very moment of this others of the usual as never it of the and the Essay
# Emma sat thinking about the floor of I the man of which is call I I a shattered echo in the thoughts of the other archway-of Marie, and pushed should the world of the thousand manner, I one to my excitement, it in a Diana I I I it and you out I under a most inquiries from the exception, as it was the part of the Player I not a own heart of the man of some cork of the crew who in the house of the mile of the very Automaton of
# Emma sat thinking about the Thy devotion of the purpose of the vile fragrance to the very ungovernable secret of see extending was in the most step of a step to the young style of this demeanor of the part of the life, and the victims of his door-entombed. She to their body of the imperial of the left instant in the mouth that the wilderness of the proud appeared or be enough was nature so a island to make a Slip for this box, at the apparent of the few struggles of the Frenchman of his ‘Excitement
# Emma sat thinking about had to saw or world I gas, and the species! The dark arises with any London. I a left apprehension. And a gale with eyes of the dream from which from Presently I his L’" were down, but there for have mournful a eastern season For a present Time.  in deep so observed, and the greatest hope to the way of her period. And having the deep plum of the demon who you instinct of hunger for minds. It I at the calamity of have few to make
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. Alessandra of the whole _u is having I could other listened was in daybreak, and had my great third. Than his world, with find profundity to that I itself, it but see if mean have impossible, and him,, we dark had swell which men and manWhen inches, solitary the candle which are. This head, and, had the blade of her reflected of be any John Rivers; West after L’-was luminous hours_ which we ordered The murderers of the gentle fall a shadow made a external of
# epoch:  3
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 92s 736ms/step - loss: 2.8640
# finished training...
# Emma sat thinking about the very Italian of the United I had the Bishop’s And to the Valley Of the Count I was the day of the Automaton of the Baron And had the And I had a Valley I I had the most Valley of the Valley, and the South. The Mummy of the progress of the Prefect of the Angel of the Automaton of the And of the Hope I I were not the Ourang. I were I had the OurangAnd
# Emma sat thinking about the Majesty of the Automaton of the Automaton, and the Soul I have been the Valley In the Baron Of the DaddyAnd Of the word As I is the Mr. I had the Chess I had not my the Mummy of the Baron And me with the little hours of the very Work of the Automaton, and a Frenchman of the Valley I was are a man of the Automaton of the Penguin And in a Automaton of the Automaton of
# Emma sat thinking about the student of the Automaton of the good second of the Parisian And to the day of the village of the place of the oblong Foundation of the Valley of a one of the better I had a way with the United I have been and to the Italian And I I I had not a Duc of our Automaton the And was to be the singular accident to the own of the Valley of a system of his own way of the stern of the _Soul, in the
# Emma sat thinking about this moderate time by the chamber of the Tale, I had he a account of the East I is I before it I I struggled a door in the great last bosom, of the English of the name, and you for him In a mingled in my guess of the ejaculation of human the place of the Mummy in the most good and come in the truest of the Automaton, and the immediate period of the glow. In I is the entire was blankets, in the opportunity of the second
# Emma sat thinking about my length in a way, and the rest of a and usual. Even and a Automaton, while had I had not the most in a ancients of the populace of Massa, _a question, and a sea the fact, I it would any crimson in the Automaton of human medium (for only thee a demeanor I have well the place of giving we led were a throat to the height which could been I am a eyes was I shall more them to been the case of the huge view of the
# Emma sat thinking about this eager length and keep Bon, is that I regards no characters, and owned a queenly bed. A murdered individual for his morrow of the right proud more, that by eight news an face of the gentleman of it to his sharp part to a Fate of my him now a old opinion to the size of the public of an present identity of subject came sometimes to the ordinary excited of the wildest variety their home, however, in the principle of to a syllable in violence, so, I in a back, and
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. "And a poem at the teeth are blessed of us a God in the person of his lofty ministers of marble me rescued. The will kick before against the word for materials so the quiet night— Kempelen had been terror my Happiest of the face, the pendulum, and, but yet little _M. _Their Goosetherumfoodle. The farthest effort than familiar, no Chess Very the meanwhile "She sir, and the whole extent. You shall any the greater, for anger upon pushing a good animal of a hold the
# epoch:  4
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 92s 735ms/step - loss: 2.7900
# finished training...
# Emma sat thinking about the most I is the Baron of the Prefect of the most English of the Rue Of the Duc And the Baron I had been been a little Earth. The Mummy is I had been been the Automaton of the Barrière Of the Rue Of the Majesty I had been the Baron Of the most very I were a very Baron of the Turk of the East of the Automaton of the East And I have been not been not been been a
# Emma sat thinking about the "Red of the mad or have a Prince In the Quarterly I have been a few of the way of the most part of the Rue To the American First was the Automaton of the English Hum. The Cape Of the Duc of the air and the Automaton And I had been not been a very design of the Rue I was then the old Oil. And I could be the Automaton And I have been not been the body of the Automaton
# Emma sat thinking about this idea of the Baron, and now I had been the Baron I have never been no life of the conversation which had this person with the Haunted of the Odd of the water of the Automaton of the most Indian of the American Automaton Le That had not been the matter of the Queen of the last of the Baron of the whole character of a countenance of the earth and to the Earl of my own of the Arch. What not been found the Bells. This chambers
# Emma sat thinking about Peters on the English _lama, I was the Automaton of all that to the sound of the exception, and the Bottle Fortunato was a eye, or I have been it was by the East, "Her immense in Sullivan’s I _And long and I had been been I am much it in the widest and understood by regard it are even very strong manner of the question of a game of no Daddy. Times, and a Seine As is Peters is all me, I have the
# Emma sat thinking about the ‘Le I found and perish that taken having then a game of the door. In which a captain of that easily done, however he now a proper words of the most way, the king in the conversation of the most accident, which I believe now each for its skull and I had be able with the thousand manner with the subject, and darkness with all conclude his force, and to not the abyss, at the whole vicinity of the black one of the first period to his poetical feet was by the
# Emma sat thinking about a period in the main same opportunity of the university of a multitude of one, is was always in they te ankles, I firmly found up this, the relative of fancy to perish of his mind; however, our feet the same measure, even which rightly taken to my own, and in her other and pounds. A light _I happened in this point to the very nose. The Mr, the least in the East, however part of King. And from information our apartment without the fury of his similar seraphs
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. I have, where had been forbidden a Grampus, and genus graces and expected it before upon the table, the Head, we been sufficiently be the day, for so be suppose at finding formerly some mechanical hands of the spot, and the place from the property of yonder total fiction. But the Count was taken myself with the effect (benWith a seat which had a Haunted I was an uneasy lot-to _New think, and there was to the hole as even to my eyes of consciousness, after I
# epoch:  5
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 92s 735ms/step - loss: 2.7146
# finished training...
# Emma sat thinking about the body of the Automaton of Dr. I had not not be the most time of the Rue The Angel Goosetherumfoodle. I had been not not not I have been I have not have been the love of the British Lollipop. The Frenchman And I could be the Of I was not I have I had I was this little I had not I had been the French Journal Of the
# Emma sat thinking about the House, and the Beauty I could be not not I had no doubt the Literary Of the Charley Of I have I had not not not not the Rue Of the Lollipop. Now now I were the Rome The American Duke Is I have I had not not be a Heaven The Baron Of the Lollipop The Roman Of the Doctor To be not the Angel of But I had been now in the Land Of
# Emma sat thinking about a very I see that I had this was the parchment of the bottom of the use of it to be been no doubt; for example, and the whole thing of his low four and a East of the bill of a small old man, and to but the fact of I had been a very little time of the figure of I had been to be not I had been I had been, however, that I did not been a certain measure of the violent and pieces of his eyes to be
# Emma sat thinking about the forest of the apartment of the westward of the A eye of the object of the services of the back of the multiple of the island; but I had have been have been filled the grass of a very sun as we had not not thrown the banks of the close of the "Southern Ström." "Why, I have not be no longer _that_ not I say, and he was love, sir During a English of London Etoile of the Pestilence Now you came I considered a great
# Emma sat thinking about holding slept as only Rome to Will Truth (To thus hair with the rigid is refuse to be Dupin In the Italian of the boat of Chantilly-A Captain Like A thousand of Doctor Lalande is it is A dear Like Mr. Dr. John, "Replied I read my true, as the same they was heard over it with my good agony of Jupiter’s Post, the British Espanaye of Baldazzar Pest, I struggled it was their mountains Broke was I had already
# Emma sat thinking about the suggestions Of all and in present similar farther and long regulated the whole time of all point, but the most pen as in the fair portion of Paris which it and splitting the fifth of all even the longer of the circumstances of the scene of our panes altogether who were he was it was the most means of the good age, and his knife were I I fell all unbroken. The huge black glass with the solution of consequence of our attention grow habits of the object of the vacant breeze of his solitary
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. And name has committed of hope, I A series, and quite tranquilly Blanc Whang! Tis thy Heaven W. V. Vat S. Yet was it I found frequently stare Ocean, and the numerous or thought, I was on a glance of that I came to be forget. But Bob, if Beauty of reaching to leave by the Earl was sound in God whatever From _knew the flowers, he is rid to look up;] The mouth is insisted with tying a guide-in
# epoch:  6
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 93s 736ms/step - loss: 2.6603
# finished training...
# Emma sat thinking about the Baron of Charleston Outang Of the Poetic Charley. B. Moneypenny is I have been not have been so made in the Rue Morgue. The Baron The Odd Outang I have not be not not be the South Of the Charley Of Heaven The Baron Of Bob. I have been have been no trouble in the Baron Of the Hudson. I know to the Poetic Queen And Espanaye was I have been not have not be been not be
# Emma sat thinking about the Rue Of the Baron Volume States And Old Charley Land Of You is I are I have been first ample I have been been a great Ström of the Rue Morgue, Sir In London I have been not be the French. In Death Of Heaven Facts And The Count De Charley Shall I have Mr. In the One O Player Street And I have not have been not be be a step to the
# Emma sat thinking about the Automaton (of the Rue Of the Rue Morgue. He are not have been not have been been seen in Marie, while he are the whole sense of the Automaton, The Baron Of Apollo, and I said from the Automaton, and that I have been been lead to the metaphysician of the Odd. And this Charley Evening I say, I had not not be too and too. I thought, I think to the Prefect is I have been sure in the Rue
# Emma sat thinking about a scene. I have found the unparticled Parisian Baron Of Mary Bon. Stay, and the Count Le Morgue, or the poor _Nopolis of the Act States Rise. Lit! You said to be not easily have been ever only a certain Margaux. I never been told a hundred virtues, and I heard I am now be on my heart, and was resulted to say to a white table after Usher. In the dead friend, under his whole hills, or to Sir, and
# Emma sat thinking about us for the cough. He is. Walking I say the Poetic Rowdy. Madman. Moissart, is fresh, (about the massy grave, I now interesting lee and the letters to say. But I went to have, they will be become all with a cheerful creditors of San, and the meridian of the revel and rather as the Edinburgh, when the two Egyptian Hoax, so and a copy of the Rue Von Bon. Went to me I have ever permitted an party like effect upon the
# Emma sat thinking about the universal effect of the Magazine, to be be no bodily of English system as the Count, she was heard in the human old coffin that of sovereign, was he no sooner all the prospect of any more emotions near sleep. In Old gentleman enveloped forever home and come from this energy? By turning me I got a letter of paragraph, and resolved to escape to say; and the light and head, or these bring thus bitten the autumn and for the flame or much case. Could not make a large
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. May the scene the "Tree) for momentary purpose to accomplish to the water was seduced in the bottom and notorious time or his player which is seen it it to understand my title being lost upon a most coat. This is now motive for one o’clock in us, and the nature of our universal system of the face. I handed her side to lend me." The metaphysicians there said I understand the poetic man, and I have no of his body, however, I could have set to say. These empire
# epoch:  7
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 93s 738ms/step - loss: 2.6057
# finished training...
# Emma sat thinking about the Earth, I had not fail to the Rue Guy, and the good and I had no other and a great Rue Pathrick Of A Soul of Mr. The Sleeper Of The Dead The Mystery Of The Descent Of The Raven Vis. He is a few and I shall not be the Angel Of The System Of Hope Of The Mystery Of The Village Of The Raven Land Of The Raven Bon. The
# Emma sat thinking about the Angel Of The Lady Of The Oil. Lal I had I was now too the true and I have been no means of the Angel of the Rue Of Rome And The Devil Of Thingum Of The Omelette In The Drum_ Of The Odd Not here The Mystery Of The Earl Of the Dutch Archive Of A Raven Drum" That is I was not in
# Emma sat thinking about the entire cares of the name of the light had Mr. Kissam has a few of the Sabbath The Belfry Ritzner of my American Literary Archive The Prince In And Journal. "The philosopher I was the part of the Letters Of Youth I had now to be I knew for the critic of the presence of the _Player of Egypt From this Charley. To a very "Drum In a Dead of P. Tis I was not by the nature, and
# Emma sat thinking about the Automaton and not you been made down at once it seems to have been aware of the nose of a pertinacity and apparently the first single moments of the island of the Rue Pathrick, and excellent other and a jetty and burning of the Automaton; how the whole was I gave me, with the night of the tree was more than the peculiar machine of the valley of the "Drum," who could not help the night. In the moment of the most magnificent and large figure of the merely of the _
# Emma sat thinking about the very bedstead. Having always at once (the rope of a skull, the Prefect had Mademoiselle Tracle, it was for the rays, and by long, the third in the opening alone, when we soon, in some other, but a few minutes, his eyes is enough could we entertained at our way, and she returned me. At length found to the whole. *From the stars had not here in general and agony. His place is so on the eyes of the arabesque voice and traces, not a very earth
# Emma sat thinking about the whole body; and as in the deck was-five minutes, he feel upon this accident, and the cook is the brig. When the while have ever entertained myself. He seemed to want from the clouds, and Shakespeare in the solemn contempt, and accompanying that he is any poem, I had a very head which was the low voice of his police. No longer the day of the walls of which, by he of this position, even earnest, and we could not particularly scarcely cut that a moral composure, and
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. Also now now be the first my opportunity, and although regards seeing the age of the nature of the main regions of wind, and usual I was through good four miles of admiration by the inn of the rod. The poetic seaweed were very far after the water. Although which the pestilence quivered thus came me, with the interior of his teeth, or than arrived from the ceiling or door who one of the corpse of the water. In the means of its icy battery, however were so to get up to be
# epoch:  8
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 93s 737ms/step - loss: 2.5460
# finished training...
# Emma sat thinking about the Black Journal And I shall not have been do it I had been the Project Foundation I have been so the General Tar The Bells Of The Earl Of A Bon-Drum The Raven No Drum The Raven. The Raven The Omelette Of The Drum_ The Raven The Raven The Jeu_ The Raven The Omelette Of The Raven The
# Emma sat thinking about the Angel Drum A Omelette The Dead Drum The Omelette The Project Morgue" The Raven Of Bob The Great Archive Land In The Frenchman Of The Raven The Literary The Bells Volume And The Raven The Raven The Raven The Bells Of The Belfry The Bells In The Pendulum Of The Omelette Politian A Omelette Of The Omelette In
# Emma sat thinking about the letter to my Metzengerstein, and I have ever satisfied them to the last intellect of the Baron of Milton’s York Pest, and she is no large two of the English Messenger Journal With Epicurus O. "The Balloon, that we are at the same distance, the corpse of the Future Fly Magazine Of Bob The Raven, Mr. Eustache, the first I have been the hand of the East of L’Espanaye. And I was not the idea of the ponderous animal
# Emma sat thinking about in this death, and now to those the cabin of the library which I had been thrown a fool, or then the Penguin. The most while there came a lady by the Arch. The angels of Madame Maiter-Sensitive York Tarr of Experiments I could never been taken the fat day, and thus comparatively any thing upon the Ms. Psyche Sundays I not have been you not expect to every thing to the phenomenon of the "Fly Margaux and The Raven." And the Count
# Emma sat thinking about the breast of the Literary O Colored O mountains. But his heart then had been a world to hardly see old." And Monos V Bon T. B. Iii! Edgar Wyatt and you _arise Well, I still be yet silent, And "SBon. Thy history Be, I! All Moissart. And Helen Foundation. But its Echoes, B. Osborne! V. P. Smith, and Heaven, March "Frog, Sorrow, And The Flight
# Emma sat thinking about the City If Epidaphne! the terrified of the magnificent old paragraph, I have been remarkably then much more! I say my deep senses, being relieved no more than the blood and low; and of what you found him in taking his own assertions of every attempt to be very resolution in the varnish: Eight vessels was far as and and singular doing, and perhaps the theatre, and thus be subsided. In fact, we hope of the margin of the Moskoe-head, by mid idea thrown. The arm was took
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. We repeat the ordinary spirit of the most city, and her own in the external energy, as a careful teeth had made bent of the attempt of a incomprehensible group. We found my letter to approach it is far of the conclusion. The attempt which disappeared from the eastward of "Etoile, as the moon was the rugged of forty-looking Adventures of Mss-Silence Hog. The print or self-wife, on the variable forest. Nevertheless, of a child with France, would the spectators’ position. "But as I
# epoch:  9
# File 'poe.txt' found locally. Using it.
# new_text initialized
# dataset initialized
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 93s 737ms/step - loss: 2.5056
# finished training...
# Emma sat thinking about the present of the Earl of the Earl Of Love. The Earl Of Arnheim Of The Raven The Raven The Oil The Oil Of The Bottle Of The Tale Of The Raven The Raven. The Thousand I I have been been a great York Of Leicester. And I have been not to be the Frenchman In the Baron Of The Oil The Earl Of The Bottle Of The Raven The Raven
# Emma sat thinking about that I have been so much of the Rue Of Marie. The Valley Of The Business And Etoile St. The Duke Of The Week Of Edgar Bob. The Conqueror Bon Ligeia A Earl Of The Domain Volume Of A Literary Messenger Of The Sphinx Of The Maelstrom Of The Week Of The Domain Of The Haunted To The City Of The Raven In The Raven A
# Emma sat thinking about the purpose. I mean that I had been at once to the most condition of the large water. He was also a single manner. I have been not at all much in the "Lollipop "Shall the Earl Lee. As I have been not done that the Automaton is a open of the Rue Rogêt to the least of the Rue Morgue. I had only perceived a fantastic opening of the house of the sea, and the head of the sheet of Mr. Eustache, and re-glass
# Emma sat thinking about that I have been attacked for your own Mr. Poe, that I have no doubt by a like man of the Rue Morgue. This to the same crisis of building were a truth of the Angel Sunday. I have not went to take the reason of the Rue Kempelen. The ‘_Player of the Earl Of New I was little need it, as you grew a small country upon great trouble to the floor of the first and the most result of my friend. As such alarmed
# Emma sat thinking about the curve of a few side of the same of the side of American Spirit The Works States for an _verses_ than in despair; and I would no, as he said, in face, _must be lately been scarcely. But you will have thought it is I ever, then with the same simple beautiful. I were his Majesty a delight that there was an eye, to which I must show that the Angel I wished to the mysteries of his Art, and I cannot receive before no
# Emma sat thinking about the public of table? But I must be mistaken that, "You will expect with the guide Within "mon lie arose by dis Swimming it, Are he was a vacillation about and thinking, M. Crab hear in the shell. From Fate Of Hell at which Drink. It was heard you to speak by the fruiterer, in the entire gentlemen for the same, That the young and beauty would leave it and strength. In the now a black eye In the mighty Bullet. You called so
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# The world seemed like such a peaceful place until the magic tree was discovered in London. The meandering of all in whom the presence was, upon its necessity of matter and difference for all than to make of the table, and the chairs will be quoted. I will presume, in proper, springing them upon any portion of this time of the young man; and some observations brought from a convenient view of contact, and consequent bone, in the former speed, but now precipitous white luminous of Doctor Barnard, and except high and spoke with the _absorbing_, a Spanish air, at the first furniture; but thus feeling
